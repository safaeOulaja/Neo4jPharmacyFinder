# %%
import osmnx as ox
import geopandas as gpd
from neo4j import GraphDatabase
import networkx as nx 
from geopy.distance import geodesic
import folium
import requests  
import webbrowser

# %%
# Spécifiez le nom de l'endroit
place_name = "Fès, Morocco"

# Télécharger les données du graphe de la ville de Fès, Maroc
graph = ox.graph_from_place(place_name, network_type="drive")

# %%
# Extraire tous les points d'intérêt (POI) de la ville de Fès pour les pharmacies
pois = ox.geometries_from_place(place_name, tags={'amenity': 'pharmacy'})

# Filtrer les géométries pour ne conserver que celles de type Point
pharmacies_gdf = gpd.GeoDataFrame(pois[pois.geometry.type == 'Point'])

# Afficher la carte de Fès
fig, ax = ox.plot_graph(graph, figsize=(10, 10), show=False, close=False, edge_color='k', node_color='w')

# Ajouter les pharmacies à la carte
ax.scatter(pharmacies_gdf['geometry'].x, pharmacies_gdf['geometry'].y, color='blue', s=50, label='Pharmacies')
# Out:
# C:\Users\aya\AppData\Local\Temp\ipykernel_21432\3334448148.py:2: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   pois = ox.geometries_from_place(place_name, tags={'amenity': 'pharmacy'})

# %%
# Afficher les noms des hôtels sous forme de liste
print("Liste des pharmacies à Fès, Maroc:")
for pharmacies_name in pharmacies_gdf['name'].unique():
    print("- ", pharmacies_name)
# Out:
# Liste des pharmacies à Fès, Maroc:
# -  Pharmacie Centrale الصيدلية المركزية
# -  Pharmacie Filali صيدلية فيلالي
# -  Pharmacie Rcif صيدلية الرصيف
# -  Pharmacie Irchad صيدلية إرشاد
# -  Pharmacie Basmati صيدلية بسمتي
# -  Pharmacie Lablida صيدلية البليدة
# -  Pharmacie la Tulipe صيدلية لاتوليب
# -  Pharmacie de la Liberté صيدلية الحرية
# -  Pharmacie les Palmiers صيدلية النخيل
# -  Pharmacie de France صيدلية فرنسا
# -  Pharmacie l'Amitié صيدلية الصداقة
# -  Pharmacie Bouslikhane صيدلية بوسليخن
# -  Pharmacie Acima صيدلية أسيما
# -  Pharmacie Echadli صيدلية الشادلي
# -  Pharmacie Allal Ben Abdellah صيدلية علال بن عبد الله
# -  Pharmacie du Maroc صيدلية المغرب
# -  Pharmacie la Criée صيدلية المزاد
# -  Pharmacie Bahja صيدلية البهجة
# -  Pharmacie de la Santé صيدلية الصحة
# -  Pharmacie Idrissi صيدلية الإدريسي
# -  Pharmacie Debbagh صيدلية الدباغ
# -  Pharmacie et Laboratoire Al Amrani صيدلية و مختبر العمراني
# -  Pharmacie Moulay El Kamel صيدلية مولاي الكامل
# -  Pharmacie Mimousa صيدلية ميموزة
# -  Pharmacie Zemmouri صيدلية الزموري
# -  Pharmacie et Laboratoire El Karaouyine صيدلية و مختبر القرويين
# -  Pharmacie Jnane Fès صيدلية جنان فاس
# -  Pharmacie Oudghiri صيدلية الودغيري
# -  Pharmacie Assalama صيدلية السلامة
# -  Pharmacie Route d'Immouzer صيدلية طريق إيموزار
# -  Pharmacie de l'Hôpital صيدلية المستشفى
# -  Pharmacie Moulay Driss صيدلية مولاي ادريس
# -  Pharmacie le Palais صيدلية القصر
# -  Pharmacie Nouzha صيدلية النزهة
# -  Pharmacie El Fath صيدلية الفتح
# -  Pharmacie la Croix Verte صيدلية لاكروا فيرت
# -  Pharmacie Marjane صيدلية مرجان
# -  Pharmacie Al Ichrak صيدلية الإشراق
# -  Pharmacie Al Mernissi صيدلية المرنيسي
# -  Pharmacie Masjid Ataqwa صيدلية مسجد التقوى
# -  Pharmacie Sounni صيدلية السني
# -  Pharmacie Bennani صيدلية بناني
# -  Pharmacie Arrachad صيدلية الرشاد
# -  Pharmacie Farah صيدلية فرح
# -  Pharmacie Belbacha صيدلية بالباشة
# -  Pharmacie Moulay Slimane صيدلية مولاي سليمان
# -  Pharmacie la Station صيدلية المحطة
# -  Pharmacie Azzahraouayn صيدلية الزهراويين
# -  Pharmacie Imam Ali صيدلية الإمام علي
# -  Pharmacie Touzani صيدلية التوزاني
# -  Pharmacie Pavlov صيدلية بافلوف
# -  Pharmacie Bab Ftouh صيدلية باب فتوح
# -  Pharmacie Al Ouafae صيدلية الوفاء
# -  Pharmacie Ben Debbab صيدلية بن دباب
# -  Pharmacie Lwdaya صيدلية لوداية
# -  Pharmacie Arrajae صيدلية الرجاء
# -  Pharmacie Bouzoubaa صيدلية بوزوبع
# -  Pharmacie El Malhi صيدلية الملحي
# -  Pharmacie El Wardi صيدلية الوردي
# -  Pharmacie Al Mawada صيدلية المودة
# -  Pharmacie Sahb El Ward صيدلية سهب الورد
# -  Pharmacie Al Ghassani صيدلية الغساني
# -  Pharmacie L'IRIS صيدلية الاغيس
# -  Pharmacie Ziat صيدلية الزيات
# -  Pharmacie Saiss صيدلية سايس
# -  Pharmacie Nahid صيدلية ناهيد
# -  Pharmacie El Attar صيدلية العطار
# -  Pharmacie Amine صيدلية أمين
# -  Pharmacie Arssat Zitoun صيدلية عرصة الزيتون
# -  Pharmacie Saidi صيدلية سعيدي
# -  Pharmacie Niama صيدلية نعمة
# -  Pharmacie El Mouahidine صيدلية الموحدين
# -  Pharmacie la Bonté صيدلية الطيبة
# -  Pharmacie Chifae صيدلية الشفاء
# -  Pharmacie des FAR صيدلية الجيش الملكي
# -  Pharmacie Doukkarat صيدلية الدكارات
# -  Pharmacie Route de Meknès صيدلية طريق مكناس
# -  Pharmacie Tazi صيدلية التازي
# -  Pharmacie Tarik صيدلية طارق
# -  Pharmacie Ait Skattou صيدلية ايت سقاطو
# -  Pharmacie Benjelloun صيدلية بنجلون
# -  Pharmacie Lalla Soukaina صيدلية للاسكينة
# -  Pharmacie la Lavande صيدلية الخزامى
# -  Pharmacie du Passage صيدلية المسار
# -  Pharmacie Ravin صيدلية الرافان
# -  Pharmacie Adarissa صيدلية أدارسة
# -  Pharmacie Yassine صيدلية ياسين
# -  Pharmacie Dhar El Mehraz صيدلية ظهر المهراز
# -  Pharmacie Jnane El Berdai صيدلية جنان البردعي
# -  Pharmacie de la Gare صيدلية المحطة
# -  Pharmacie Hay El Anbra صيدلية حي العنبرة
# -  Pharmacie Saadi صيدلية السعدي
# -  Pharmacie Ain Amir صيدلية عين عمير
# -  Pharmacie Boulevard du Joulane صيدلية شارع الجولان
# -  Pharmacie Ville Nouvelle صيدلية المدينة الجديدة
# -  Pharmacie du Boulevard صيدلية الشارع
# -  Pharmacie Mariam صيدلية مريم
# -  Pharmacie Oum Al Banine صيدلية أم البنين
# -  Pharmacie Sebti صيدلية السبتي
# -  Pharmacie la Commune صيدلية الجماعة الجديدة
# -  Pharmacie Youssra صيدلية يسرى
# -  Pharmacie Ilyas صيدلية إلياس
# -  Pharmacie Bab Alghoul صيدلية باب الغول
# -  Pharmacie Marhaba صيدلية مرحبا
# -  Pharmacie Bahia صيدلية باهية
# -  Pharmacie Boughafer صيدلية بوغافر
# -  Pharmacie Al Farabi صيدلية الفرابي
# -  Pharmacie Zakaria صيدلية زكرياء
# -  Pharmacie Chaymae صيدلية شيماء
# -  Pharmacie Ibn Haitam صيدلية بن الهيثم
# -  Pharmacie El Azhar صيدلية الأزهر
# -  Pharmacie Ibn Al Hassan صيدلية ابن الحسن
# -  Pharmacie Iraqi Karima صيدلية عراقي كريمة
# -  Pharmacie Al Ambra  صيدلية العنبرة
# -  Pharmacie Al Irfane صيدلية العرفان
# -  Pharmacie Amal Achifae صيدلية أمل الشفاء
# -  Pharmacie Mil Roses صيدلية ألف زهرة
# -  Pharmacie Badr صيدلية بدر
# -  Pharmacie Azzahrae صيدلية الزهراء
# -  Pharmacie Agdal صيدلية أكدال
# -  Pharmacie Labaraka صيدلية البركة
# -  Pharmacie Ennassiri صيدلية الناصري
# -  Pharmacie Omari صيدلية عماري
# -  Pharmacie Demnati صيدلية الدمناتي
# -  Pharmacie Platanes صيدلية السيجان
# -  Pharmacie de l'Atlas صيدلية الأطلس
# -  Pharmacie Afifa صيدلية عفيفة
# -  Pharmacie Ifrane صيدلية إفران
# -  Pharmacie Al Korachi صيدلية القرشي
# -  Pharmacie Jabri صيدلية جابري
# -  Pharmacie L'Opera صيدلية الأوبرا
# -  Pharmacie Erriad صيدلية الرياض
# -  Pharmacie Mekouar صيدلية مكوار
# -  Pharmacie Pasteur صيدلية باستور
# -  Pharmacie Arrazi صيدلية الرازي
# -  Pharmacie Conseil صيدلية النصيحة
# -  Pharmacie Al Ihssane صيدلية الإحسان
# -  Pharmacie El Karam صيدلية الكرم
# -  Pharmacie Blanco صيدلية بلانكو
# -  Pharmacie El Majd صيدلية المجد
# -  Pharmacie Al Ahbab صيدلية الأحباب
# -  Pharmacie Taiba صيدلية طيبة
# -  Pharmacie Ibn Khaldoun صيدلية ابن خلدون
# -  Pharmacie C.H.U Hassan II صيدلية الحسن الثاني
# -  Pharmacie Al Inaya صيدلية العناية
# -  Pharmacie Al Ikhwa صيدلية الإخوة
# -  Pharmacie Haoudi صيدلية هاودي
# -  Pharmacie Najmi صيدلية نجمي
# -  Pharmacie La Victoire صيدلية النصر
# -  Pharmacie Fatima Ezzahra صيدلية فاطمة الزهراء
# -  Pharmacie El Houda صيدلية الهدى
# -  Pharmacie Bakkali صيدلية البقالي
# -  Pharmacie Florida صيدلية فلوريدا
# -  Pharmacie Mont Fleuri صيدلية الجبل
# -  Pharmacie Al Yousr صيدلية اليسر
# -  Pharmacie Al Fadila صيدلية الفضيلة
# -  Pharmacie Ryad صيدلية الرياض
# -  Pharmacie Ghizlane صيدلية غزلان
# -  Pharmacie l'Entente صيدلية الإتفاق
# -  Pharmacie Route de Sefrou صيدلية طريق صفرو
# -  Pharmacie Faculté de Médecine صيدلية كلية الطب
# -  Pharmacie Fès Shore صيدلية فاس شور
# -  Pharmacie Nour El Houda صيدلية نور الهدى
# -  Pharmacie Champs de Courses صيدلية ملعب الخيل
# -  Pharmacie Firdaous صيدلية الفردوس
# -  Pharmacie de l'Hôpital Universitaire صيدلية المستشفى الجامعي
# -  Pharmacie Ibn Hazm صيدلية بن حزم
# -  Pharmacie Yasmine صيدلية ياسمين
# -  Pharmacie Ben Cheikh صيدلية ابن الشيخ
# -  Pharmacie Al Wassila صيدلية الوسيلة
# -  Pharmacie Al Fajr صيدلية الفجر
# -  Pharmacie Beyrout صيدلية بيروت
# -  Pharmacie Lahbabi صيدلية لحبابي
# -  Pharmacie le Docteur صيدلية الدكتور
# -  Pharmacie Mourchid صيدلية مرشد
# -  Pharmacie Complexe Sportif صيدلية المركب الرياضي
# -  Pharmacie Lina صيدلية لينة
# -  Pharmacie Azzouzi صيدلية عزوزي
# -  Pharmacie Yousfi صيدلية يوسفي
# -  Pharmacie Sidi Brahim صيدلية سيدي ابراهيم
# -  Pharmacie Noureddine صيدلية نور الدين
# -  Pharmacie du Quartier Industriel صيدلية الحي الصناعي
# -  Pharmacie Talbi صيدلية طالبي
# -  Pharmacie Al Ikhlasse صيدلية الإخلاص
# -  Pharmacie Zohour صيدلية الزهور
# -  Pharmacie Al Akhawayn صيدلية الأخوين
# -  Pharmacie Hay El Hassani صيدلية حي الحساني
# -  Pharmacie Narjiss صيدلية النرجس
# -  Pharmacie Ismailia صيدلية الإسماعيلية
# -  Pharmacie Cotef صيدلية كوطيف
# -  Pharmacie Saoussane صيدلية سوسن
# -  Pharmacie La Famille صيدلية العائلة
# -  Pharmacie Hameda Benchekroun صيدلية حميدة بنشقرون
# -  Pharmacie La Suite صيدلية لاسويط
# -  Pharmacie Makro صيدلية ماكرو
# -  La Grande Pharmacie الصيدلية الكبرى
# -  Pharmacie El Boutahri صيدلي البوطهري
# -  Pharmacie Assafwa صيدلية الصفوة
# -  Pharmacie El Hijazi صيدلية الحجازي
# -  Pharmacie Sandra صيدلية ساندرا
# -  Pharmacie Zouagha Bas صيدلية الزواغة السفلى
# -  Pharmacie Al Hamd صيدلية الحمد
# -  Pharmacie El Qods صيدلية القدس
# -  Pharmacie L'Avenir صيدلية المستقبل
# -  Pharmacie Al Marja صيدلية المرجة
# -  Pharmacie Attaakhi صيدلية التآخي
# -  Pharmacie Arreda صيدلية الرضا
# -  Pharmacie Sefrioui صيدلية الصفريوي
# -  Pharmacie Diamant Vert صيدلية الجوهرة الخضراء
# -  Pharmacie Ouad El Jawahir صيدلية واد الجواهر
# -  Pharmacie Wafi صيدلية الوافي
# -  Pharmacie Espace Santé صيدلية فضاء الصحة
# -  Pharmacie Haj Bensalem صيدلية الحاج بنسالم
# -  Pharmacie Italia صيدلية إيطاليا
# -  Pharmacie Al Najoua صيدلية النجوى
# -  Pharmacie El Iraki صيدلية العراقي
# -  Pharmacie Al Oumma صيدلية الأمة
# -  Pharmacie Zouagha صيدلية الزواغة
# -  Pharmacie Bensouda صيدلية بن سودة
# -  Pharmacie Av Med VI صيدلية شارع محمد السادس
# -  Pharmacie des Sciences صيدلية العلوم
# -  Pharmacie Sekkat صيدلية السقاط
# -  Pharmacie Al Wahda صيدلية الوحدة
# -  Pharmacie Kandoussi صيدلية القندوسي
# -  Pharmacie Ain Smen صيدلية عين السمن
# -  Pharmacie Errachidia صيدلية الراشدية
# -  Pharmacie Al Wissal صيدلية الوصال
# -  Pharmacie Al Kaoutar صيدلية الكوثر
# -  Pharmacie Nassim صيدلية النسيم
# -  Pharmacie Al Abaouayne صيدلية الأبوين
# -  Pharmacie Fahmi صيدلية فهمي
# -  Pharmacie Ayoub صيدلية أيوب سيد الهادي
# -  Pharmacie Basma
# -  Pharmacie Annamae صيدلية النماء
# -  Pharmacie la Ferraille صيدلية لافيراي
# -  Pharmacie le Coin صيدلية الركن
# -  Pharmacie Sanabil صيدلية السنابل
# -  Pharmacie Dar Es-Salam صيدلية دار السلام
# -  Pharmacie Addoha صيدلية الضحى
# -  Pharmacie Oum El Koura صيدلية أم القرى
# -  Pharmacie Al Farouk صيدلية الفاروق
# -  Pharmacie Sidi El Hadi صيدلية سيدي الهادي
# -  Pharmacie Al Khattabi صيدلية الخطابي
# -  Pharmacie des Roches صيدلية الصخور
# -  Pharmacie Sagha صيدلية الصاغة
# -  Pharmacie Chifae Arrahmane صيدلية شفاء الرحمان
# -  Pharmacie Jardin de Tghath صيدلية حديقة تغاث
# -  Pharmacie Errachid صيدلية الرشيد
# -  Pharmacie Al Imam Mouslim صيدلية الإمام مسلم
# -  Pharmacie Dar Dmana صيدلية دار الضمانة
# -  Pharmacie Al Youmne صيدلية اليمن
# -  Pharmacie Volubilis صيدلية وليلي
# -  Pharmacie Riad Chafi صيدلية رياض الشافي
# -  Pharmacie Asmae صيدلية أسماء
# -  Pharmacie du Lido صيدلية الليدو
# -  Pharmacie Saada صيدلية السعادة
# -  Pharmacie Gharnata صيدلية غرناطة
# -  Pharmacie Berrada صيدلية برادة
# -  Pharmacie Averroès صيدلية ابن رشد
# -  Pharmacie Attouraya صيدلية الثريا
# -  Pharmacie Hay Belkhayat صيدلية حي بلخياط
# -  Pharmacie Al Mamalik صيدلية الممالك
# -  Pharmacie le Remède صيدلية الدواء
# -  Pharmacie Ain Kadouss صيدلية عين قادوس
# -  Pharmacie Benkirane صيدلية بنكيران
# -  Pharmacie El Ghazi صيدلية الغازي
# -  Pharmacie Jbel Tghat صيدلية جبل ثغات
# -  Pharmacie Faiza صيدلية فايزة
# -  Pharmacie Salah صيدلية صلاح
# -  Pharmacie Reda صيدلية رضا
# -  Pharmacie Al Imane صيدلية الإيمان
# -  Pharmacie Al Falah صيدلية الفلاح
# -  Pharmacie Ain Haroun صيدلية عين هارون
# -  Pharmacie Ibn Al Khatib صيدلية بن الخطيب
# -  Pharmacie Agadir صيدلية أكادير
# -  Pharmacie Saida صيدلية سعيدة
# -  Pharmacie Es-Salam صيدلية السلام
# -  Pharmacie Ibn Sina صيدلية ابن سينا
# -  Pharmacie Dayaa صيدلية الضيعة
# -  Pharmacie Hay Laalou صيدلية حي لعلو
# -  Pharmacie Al Imam Malik صيدلية الإمام مالك
# -  Pharmacie Al Marwa صيدلية المروى
# -  Pharmacie Al Hilal صيدلية الهلال
# -  Pharmacie Soundous صيدلية السندس
# -  Pharmacie El Boukhari صيدلية البخاري
# -  Pharmacie Mounia صيدلية مونية
# -  Pharmacie Youssef Ben Tachafine صيدلية يوسف تاشفين
# -  Pharmacie Lhoumadi صيدلية لحومادي
# -  Pharmacie Maalal صيدلية معلال
# -  Pharmacie Hasnaoui صيدلية الحسناوي
# -  Pharmacie Dr Obtel صيدلية د.أوبتيل
# -  Pharmacie El Mountazah صيدلية المنتزه
# -  Pharmacie Nasma صيدلية نسمة
# -  Pharmacie Al Hanae صيدلية الهناء
# -  Pharmacie Bled Tahiriyine صيدلية بلاد الطاهريين
# -  Pharmacie Al Makkiya صيدلية المكية
# -  Pharmacie Driss صيدلية إدريس
# -  Pharmacie Wisslane صيدلية ويسلان
# -  Pharmacie El Louizatt صيدلية اللويزات
# -  Pharmacie M'sella صيدلية المصلى
# -  Pharmacie la Ménara صيدلية المنارة
# -  Pharmacie Kamal صيدلية كمال
# -  Pharmacie Saguia Lhamra صيدلية الساقية الحمراء
# -  Pharmacie Aouinat El Hajjaj صيدلية عوينات الحجاج
# -  Pharmacie El Alj صيدلية العلج
# -  Pharmacie Alae Arrahman صيدلية الرحمان
# -  Pharmacie Bab Fès صيدلية باب فاس
# -  Pharmacie Moulay M'Barek صيدلية مولاي مبارك
# -  Pharmacie Ain Nokbi صيدلية عين النقبي
# -  Pharmacie El Kobba صيدلية القبة
# -  Pharmacie Jnane Kadiri صيدلية جنان القادري
# -  Pharmacie Al Andalous صيدلية الأندلس
# -  Pharmacie Jnan Mekouar صيدلية جنان مكوار
# -  Pharmacie Fatima Al Fihriya صيدلية فاطمة الفهرية
# -  Pharmacie Zkak Lahjar صيدلية زقاق الحجر
# -  Pharmacie Bab El Guissa صيدلية باب عجيسة
# -  Pharmacie Oued Zhoun صيدلية واد الزحون
# -  Pharmacie Zarouk صيدلية زروق
# -  Pharmacie Hanane صيدلية حنان
# -  Pharmacie Jnan Drader صيدلية جنان الدرادر
# -  Pharmacie Sidi Boujida صيدلية سيدي بوجيدة
# -  Pharmacie Ibn Battouta صيدلية بن بطوطة
# -  Pharmacie Al Anouar صيدلية الأنوار
# -  Pharmacie Bab El Hamraa صيدلية باب الحمراء
# -  Pharmacie Lagzira صيدلية الجزيرة
# -  Pharmacie Tadlaoui صيدلية التدلاوي
# -  Pharmacie Bouramana صيدلية بورمانة
# -  Pharmacie de Paris صيدلية باريس
# -  Pharmacie Ibn Taymiya صيدلية بن تيمية
# -  Pharmacie Slaoui صيدلية السلاوي
# -  Pharmacie Meliani صيدلية ملياني
# -  Pharmacie El Kadiri صيدلية القادري
# -  Pharmacie Arrayhane صيدلية الريحان
# -  Pharmacie Almaz صيدلية ألماز
# -  Pharmacie Faculté Echariaa صيدلية كلية الشريعة
# -  Pharmacie Diamant de Fès صيدلية جوهرة فاس
# -  Pharmacie Route Sidi Hrazem صيدلية طريق سيدي حرازم
# -  Pharmacie Menzeh Saïss صيدلية منزه سايس
# -  Pharmacie Guard صيدلية كارد
# -  Pharmacie Ibno Tachefine صيدلية ابن تاشفين
# -  Pharmacie Essania صيدلية السانية
# -  Pharmacie Bel Air صيدلية بلير
# -  Pharmacie Ryad Saiss صيدلية رياض سايس
# -  Pharmacie Hay Riyad صيدلية حي الرياض
# -  Pharmacie El Otmani صيدلية العثماني
# -  Pharmacie de l'Université صيدلية الجامعة
# -  Pharmacie Al Alia صيدلية العالية
# -  Pharmacie Masjid Arreda صيدلية مسجد الرضى
# -  Pharmacie des 3 Sources صيدلية المنابع الثلاث
# -  Pharmacie Jamai صيدلية الجامعي
# -  Pharmacie Rachidia 3 صيدلية الراشدية
# -  Pharmacie Al Alaoui صيدلية العلوي
# -  Pharmacie Riad El Yassamine صيدلية رياض الياسمين
# -  Pharmacie Steven صيدلية ستيفن
# -  Pharmacie Technologie صيدلية التكنولوجيا
# -  Pharmacie Socrate صيدلية سقراط
# -  Pharmacie Zahraoui صيدلية الزهراوي
# -  Pharmacie Al Madina صيدلية المدينة
# -  Pharmacie Borj Ennakhil صيدلية برج النخيل
# -  Pharmacie Zineb صيدلية زينب
# -  Pharmacie Ahel Fès صيدلية أهل فاس
# -  Pharmacie California صيدلية كاليفورنيا
# -  Pharmacie El Aziza صيدلية العزيزة
# -  Pharmacie Rihab صيدلية رحاب
# -  Pharmacie Bennouna صيدلية بنونة
# -  Pharmacie Aida صيدلية عايدة
# -  Pharmacie Ghrissi صيدلية غريسي
# -  Pharmacie Al Jawaher صيدلية الجواهر
# -  Pharmacie Route Ras Lma صيدلية طريق راس الما
# -  Pharmacie Zahir صيدلية زاهر
# -  Pharmacie Aicha صيدلية عائشة
# -  Pharmacie Ghita صيدلية غيثة
# -  Pharmacie Khawarizmi صيدلية الخوارزمي
# -  Pharmacie Assafae صيدلية الصفاء
# -  Pharmacie Dalia صيدلية الدالية
# -  Pharmacie des Champs صيدلية الحقول
# -  Pharmacie Moussaoui صيدلية موساوي
# -  Pharmacie Al Omnia صيدلية الأمنية
# -  Pharmacie Paraconfiance صيدلية باراكونفيونس
# -  Pharmacie Nellia صيدلية نيليا
# -  Pharmacie Tajmouati صيدلية تجموعتي
# -  Pharmacie El Borj صيدلية البرج
# -  Pharmacie Hay Benslimane صيدلية حي بنسليمان
# -  Pharmacie de Fès صيدلية فاس
# -  Pharmacie Ouandou صيدلية واندو
# -  Pharmacie Nationale

# %% [markdown]
# # Insertion des Pharmacies dans Neo4j

# %%
# Fonction pour établir une connexion à la base de données Neo4j
def connect_to_neo4j(uri, user, password):
    return GraphDatabase.driver(uri, auth=(user, password))

# Spécifiez les informations de connexion à votre base de données Neo4j
uri = "bolt://localhost:7687"
user = "neo4j"
password = ""

# Établissez une connexion à la base de données Neo4j
driver = connect_to_neo4j(uri, user, password)

# %%
# Définissez une fonction pour insérer les données des pharmacies dans Neo4j
def insert_pharmacies_to_neo4j(pharmacies_gdf):
    with driver.session() as session:
        # Supprimez d'abord toutes les pharmacies existantes
        session.run("MATCH (p:Pharmacie) DETACH DELETE p")
        
        # Insérez les nouvelles pharmacies
        for idx, row in pharmacies_gdf.iterrows():
            cypher_query = (
                "CREATE (p:Pharmacie {id: $id, name: $name, latitude: $latitude, longitude: $longitude})"
            )
            session.run(cypher_query, id=str(idx), name=row.get('name', f'Pharmacie {idx}'), latitude=row['geometry'].y, longitude=row['geometry'].x)

# Utilisation de la fonction pour insérer les pharmacies et la localisation dans Neo4j
insert_pharmacies_to_neo4j(pharmacies_gdf)

print("Les données des pharmacies ont été insérées dans Neo4j avec succès.")
# Out:
# Les données des pharmacies ont été insérées dans Neo4j avec succès.

# %%
import geocoder
def get_current_location():
    # Utilisez la fonction ip() pour obtenir l'emplacement basé sur votre adresse IP
    location = geocoder.ip('me')
    return location.latlng  # Renvoie une liste contenant la latitude et la longitude

current_location = get_current_location()
if current_location:
    latitude, longitude = current_location

latitude,longitude
# Out:
# (34.261, -6.5802)

# %% [markdown]
# # Insérer la localisation actuelle dans Neo4j

# %%
#current_location = {"latitude": latitude, "longitude": longitude}
# Fonction pour insérer la localisation dans Neo4j
def insert_location_to_neo4j(current_location):
    with driver.session() as session:
        # Supprimez d'abord tous les emplacements existants
        session.run("MATCH (l:Location) DETACH DELETE l")
        # Insérez la localisation dans la base de données
        session.run("CREATE (l:Location {latitude: $latitude, longitude: $longitude})", 
                    latitude=current_location[0], longitude=current_location[1])

# Définition de la localisation actuelle
current_location = (34.034589672957686, -4.9759245423286735)

# Utilisation de la fonction pour insérer la localisation dans Neo4j
insert_location_to_neo4j(current_location)

print("La localisation a été insérée dans Neo4j avec succès.")
# Out:
# La localisation a été insérée dans Neo4j avec succès.

# %%
# Fonction pour calculer la distance entre deux points
def calculate_distance(lat1, lon1, lat2, lon2):
    return geodesic((lat1, lon1), (lat2, lon2)).kilometers

# Fonction pour créer des relations ROAD entre les pharmacies
def create_road_relations(driver, max_distance=0.5):
    with driver.session() as session:
        # Récupérer toutes les pharmacies
        pharmacies = session.run("MATCH (p:Pharmacie) RETURN p.id as id, p.latitude as latitude, p.longitude as longitude").data()
        
        # Créer des relations ROAD entre les pharmacies à moins de max_distance km l'une de l'autre
        for i in range(len(pharmacies)):
            for j in range(i+1, len(pharmacies)):
                distance = calculate_distance(pharmacies[i]['latitude'], pharmacies[i]['longitude'],
                                              pharmacies[j]['latitude'], pharmacies[j]['longitude'])
                if distance <= max_distance:
                    session.run("MATCH (p1:Pharmacie {id: $id1}), (p2:Pharmacie {id: $id2}) "
                                "CREATE (p1)-[:ROAD {distance: $distance}]->(p2)",
                                id1=pharmacies[i]['id'], id2=pharmacies[j]['id'], distance=distance)

# Appel de la fonction pour créer les relations ROAD
create_road_relations(driver)

# %% [markdown]
# # Trouver la pharmacie la plus proche avec la requête Cypher

# %%
# Fonction pour trouver la pharmacie la plus proche
def find_nearest_pharmacy():
    query = """
    MATCH (l:Location), (p:Pharmacie)
    WITH l, p,
    point.distance(point({latitude: l.latitude, longitude: l.longitude}), point({latitude: p.latitude, longitude: p.longitude})) AS dist
    RETURN p.id AS id, p.name AS name, dist
    ORDER BY dist ASC
    LIMIT 1
    """
    with driver.session() as session:
        result = session.run(query).single()
        return result['id'], result['name'], result['dist']

nearest_pharmacy_id, nearest_pharmacy_name, nearest_pharmacy_distance = find_nearest_pharmacy()
print(f"La pharmacie la plus proche est {nearest_pharmacy_name} avec une distance de {nearest_pharmacy_distance:.2f} m")
# Out:
# La pharmacie la plus proche est Pharmacie Youssra صيدلية يسرى avec une distance de 795.31 m

# %% [markdown]
# # Créer une relation entre la localisation courante et la pharmacie la plus proche

# %%
# Fonction pour créer une relation entre la localisation courante et la pharmacie la plus proche
def create_nearest_pharmacy_relation(nearest_pharmacy_id, distance):
    query = """
    MATCH (l:Location), (p:Pharmacie {id: $id})
    CREATE (l)-[:NEAR {distance: $distance}]->(p)
    """
    with driver.session() as session:
        session.run(query, id=nearest_pharmacy_id, distance=distance)

create_nearest_pharmacy_relation(nearest_pharmacy_id, nearest_pharmacy_distance)
print(f"Relation créée entre la localisation courante et la pharmacie {nearest_pharmacy_name}.")
# Out:
# Relation créée entre la localisation courante et la pharmacie Pharmacie Youssra صيدلية يسرى.

# %%
# Fonction pour trouver la localisation courante et la pharmacie la plus proche
def get_current_location_and_nearest_pharmacy():
    query = """
    MATCH (l:Location)
    OPTIONAL MATCH (l)-[r:NEAR]->(p:Pharmacie)
    RETURN l.latitude AS current_latitude, l.longitude AS current_longitude, p.id AS pharmacy_id, p.latitude AS pharmacy_latitude, p.longitude AS pharmacy_longitude
    """
    with driver.session() as session:
        result = session.run(query).single()
        return result

result = get_current_location_and_nearest_pharmacy()
current_latitude = result['current_latitude']
current_longitude = result['current_longitude']
pharmacy_latitude = result['pharmacy_latitude']
pharmacy_longitude = result['pharmacy_longitude']

print(f"Current location: {current_latitude}, {current_longitude}")
print(f"Nearest pharmacy: {pharmacy_latitude}, {pharmacy_longitude}")
# Out:
# Current location: 34.034589672957686, -4.9759245423286735
# Nearest pharmacy: 34.0293711, -4.9818124

# %%
# Fonction pour trouver la pharmacie la plus proche
def find_nearest_pharmacy():
    query = """
    MATCH (l:Location), (p:Pharmacie)
    WITH l, p,
    point.distance(point({latitude: l.latitude, longitude: l.longitude}), point({latitude: p.latitude, longitude: p.longitude})) AS dist
    RETURN p.id AS id, p.name AS name, p.latitude AS latitude, p.longitude AS longitude, dist
    ORDER BY dist ASC
    LIMIT 1
    """
    with driver.session() as session:
        result = session.run(query).single()
        if result:
            return {
                'id': result['id'],
                'name': result['name'],
                'latitude': result['latitude'],
                'longitude': result['longitude'],
                'distance': result['dist']
            }
        else:
            return None

# Utilisation de la fonction pour trouver la pharmacie la plus proche
nearest_pharmacy = find_nearest_pharmacy()

# %%
# Fonction pour obtenir l'itinéraire entre deux points
def get_route(start, end):
    url = f'http://router.project-osrm.org/route/v1/driving/{start[1]},{start[0]};{end[1]},{end[0]}?overview=full&geometries=geojson'
    response = requests.get(url)
    data = response.json()
    if 'routes' in data and data['routes']:
        route = data['routes'][0]['geometry']['coordinates']
        return [(coord[1], coord[0]) for coord in route]
    else:
        raise Exception("No route found")

# %%
# Obtention de la position actuelle
latitude, longitude = current_location
print(f"Votre position actuelle: Latitude: {latitude}, Longitude: {longitude}")

if nearest_pharmacy:
    print(f"La pharmacie la plus proche est '{nearest_pharmacy['name']}' à une distance de {nearest_pharmacy['distance']:.2f} mètres.")
    
    # Création de la carte
    map_ = folium.Map(location=[latitude, longitude], zoom_start=15)

    # Ajout d'un marqueur pour l'emplacement actuel
    folium.Marker(
        location=[latitude, longitude],
        popup='Votre position actuelle',
        icon=folium.Icon(color='blue')
    ).add_to(map_)

    # Ajout d'un marqueur pour la pharmacie la plus proche
    folium.Marker(
        location=[nearest_pharmacy['latitude'], nearest_pharmacy['longitude']],
        popup=f"Pharmacie: {nearest_pharmacy['name']}",
        icon=folium.Icon(color='red')
    ).add_to(map_)

    # Obtention de l'itinéraire entre l'emplacement actuel et la pharmacie la plus proche
    try:
        route = get_route((latitude, longitude), (nearest_pharmacy['latitude'], nearest_pharmacy['longitude']))

        # Ajout du chemin entre l'emplacement actuel et la pharmacie la plus proche
        folium.PolyLine(
            locations=route,
            color='green'
        ).add_to(map_)
    except Exception as e:
        print(f"Erreur lors de la récupération de l'itinéraire: {e}")

    # Sauvegarde de la carte dans un fichier HTML
    map_file = 'map.html'
    map_.save(map_file)
    print(f"Carte sauvegardée sous le nom '{map_file}'. Ouvrez ce fichier dans un navigateur pour voir la carte.")

    # Ouverture automatique de la carte dans le navigateur
    webbrowser.open(map_file)
else:
    print("Aucune pharmacie trouvée à proximité.")
# Out:
# Votre position actuelle: Latitude: 34.034589672957686, Longitude: -4.9759245423286735
# La pharmacie la plus proche est 'Pharmacie Youssra صيدلية يسرى' à une distance de 795.31 mètres.
# Carte sauvegardée sous le nom 'map.html'. Ouvrez ce fichier dans un navigateur pour voir la carte.
